# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Specify the path to the CSV files
file_path1 = r'/Users/sudharsanvasudevan/Desktop/Scalable DB /Project 1/SD-Pro2/Hospital_inpatient_discharges.csv'
file_path2 = r'/Users/sudharsanvasudevan/Desktop/Scalable DB /Project 1/SD-Pro2/NYC_EH_DataPortal.csv'
file_path3 = r'/Users/sudharsanvasudevan/Desktop/Scalable DB /Project 1/SD-Pro2/Air_Quality.csv'

# %%
# Load the three datasets (assuming they are CSV files)
hospital_data = pd.read_csv(file_path1)
health_data = pd.read_csv(file_path2)
air_quality_data = pd.read_csv(file_path3)

# %%
# Display the first few rows of each dataset to understand their structure
print("Hospital Data - First 5 rows:")
display(hospital_data.head())

print("Environmental Health Data - First 5 rows:")
display(health_data.head())

print("Air Quality Data - First 5 rows:")
display(air_quality_data.head())
# Out:
# Hospital Data - First 5 rows:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         New York City           Bronx                     7000006.0
# 1         New York City           Bronx                     7000006.0
# 2         New York City           Bronx                     7000006.0
# 3         New York City           Bronx                     7000006.0
# 4         New York City           Bronx                     7000006.0
#
#    Permanent Facility Id                                      Facility Name  \
# 0                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
# 1                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
# 2                 1168.0       Montefiore Medical Center-Wakefield Hospital
# 3                 3058.0  Montefiore Med Center - Jack D Weiler Hosp of ...
# 4                 1169.0  Montefiore Medical Center - Henry & Lucy Moses...
#
#      Age Group Zip Code - 3 digits Gender                    Race  \
# 0  70 or Older                 104      M              Other Race
# 1     50 to 69                 104      F                   White
# 2     18 to 29                 104      F              Other Race
# 3  70 or Older                 104      M              Other Race
# 4     50 to 69                 104      F  Black/African American
#
#            Ethnicity  ... APR Severity of Illness Description  \
# 0   Spanish/Hispanic  ...                               Major
# 1  Not Span/Hispanic  ...                            Moderate
# 2   Spanish/Hispanic  ...                               Minor
# 3   Spanish/Hispanic  ...                               Major
# 4  Not Span/Hispanic  ...                            Moderate
#
#   APR Risk of Mortality APR Medical Surgical Description  \
# 0               Extreme                          Medical
# 1                 Minor                          Medical
# 2                 Minor                         Surgical
# 3                 Major                          Medical
# 4                 Minor                          Medical
#
#          Payment Typology 1 Payment Typology 2 Payment Typology 3  \
# 0                  Medicare           Medicaid                NaN
# 1  Private Health Insurance                NaN                NaN
# 2                  Medicaid                NaN                NaN
# 3                  Medicare           Medicaid                NaN
# 4                  Medicare           Medicaid                NaN
#
#   Birth Weight Emergency Department Indicator  Total Charges Total Costs
# 0          NaN                              Y      320922.43    60241.34
# 1          NaN                              Y       61665.22     9180.69
# 2          NaN                              N       42705.34    11366.50
# 3          NaN                              Y       72700.17    12111.75
# 4          NaN                              Y       55562.51     8339.72
#
# [5 rows x 33 columns]
# Environmental Health Data - First 5 rows:
#    TimePeriod GeoTypeDesc  GeoID  GeoRank      Geography  \
# 0        2022    Citywide      1        0  New York City
# 1        2022     Borough      1        1          Bronx
# 2        2022     Borough      2        1       Brooklyn
# 3        2022     Borough      3        1      Manhattan
# 4        2022     Borough      4        1         Queens
#
#    Age-adjusted rate per 10000  Estimated annual rate per 10000  Number
# 0                         54.9                             53.6  35,778
# 1                        114.0                            113.2  11,850
# 2                         52.4                             51.2  10,351
# 3                         50.1                             48.8   6,700
# 4                         31.1                             29.8   5,479
# Air Quality Data - First 5 rows:
#    Unique ID  Indicator ID                  Name Measure Measure Info  \
# 0     216498           386            Ozone (O3)    Mean          ppb
# 1     216499           386            Ozone (O3)    Mean          ppb
# 2     219969           386            Ozone (O3)    Mean          ppb
# 3     219970           386            Ozone (O3)    Mean          ppb
# 4     164876           383  Sulfur Dioxide (SO2)    Mean          ppb
#
#   Geo Type Name  Geo Join ID                    Geo Place Name  \
# 0            CD          313               Coney Island (CD13)
# 1            CD          313               Coney Island (CD13)
# 2       Borough            1                             Bronx
# 3       Borough            1                             Bronx
# 4            CD          211  Morris Park and Bronxdale (CD11)
#
#       Time Period Start_Date  Data Value  Message
# 0     Summer 2013   6/1/2013       34.64      NaN
# 1     Summer 2014   6/1/2014       33.22      NaN
# 2     Summer 2013   6/1/2013       31.25      NaN
# 3     Summer 2014   6/1/2014       31.15      NaN
# 4  Winter 2008-09  12/1/2008        5.89      NaN

# %%
#Data Exploration 

# Information about dataset and summary statistics
print("Hospital Data Info:")
hospital_data.info()
print("Hospital Data Summary Statistics:")
display(hospital_data.describe())

print("Health Data Info:")
health_data.info()
print("Environmental Health Data Summary Statistics:")
display(health_data.describe())

print("Air Quality Data Info:")
air_quality_data.info()

print("Air Quality Data Summary Statistics:")
display(air_quality_data.describe())
# Out:
# Hospital Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1999 entries, 0 to 1998
# Data columns (total 33 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Hospital Service Area                1990 non-null   object
#  1   Hospital County                      1990 non-null   object
#  2   Operating Certificate Number         1990 non-null   float64
#  3   Permanent Facility Id                1990 non-null   float64
#  4   Facility Name                        1999 non-null   object
#  5   Age Group                            1999 non-null   object
#  6   Zip Code - 3 digits                  1954 non-null   object
#  7   Gender                               1999 non-null   object
#  8   Race                                 1999 non-null   object
#  9   Ethnicity                            1999 non-null   object
#  10  Length of Stay                       1999 non-null   object
#  11  Type of Admission                    1999 non-null   object
#  12  Patient Disposition                  1999 non-null   object
#  13  Discharge Year                       1999 non-null   int64
#  14  CCSR Diagnosis Code                  1999 non-null   object
#  15  CCSR Diagnosis Description           1999 non-null   object
#  16  CCSR Procedure Code                  1529 non-null   object
#  17  CCSR Procedure Description           1529 non-null   object
#  18  APR DRG Code                         1999 non-null   int64
#  19  APR DRG Description                  1999 non-null   object
#  20  APR MDC Code                         1999 non-null   int64
#  21  APR MDC Description                  1999 non-null   object
#  22  APR Severity of Illness Code         1999 non-null   int64
#  23  APR Severity of Illness Description  1999 non-null   object
#  24  APR Risk of Mortality                1999 non-null   object
#  25  APR Medical Surgical Description     1999 non-null   object
#  26  Payment Typology 1                   1999 non-null   object
#  27  Payment Typology 2                   636 non-null    object
#  28  Payment Typology 3                   189 non-null    object
#  29  Birth Weight                         399 non-null    float64
#  30  Emergency Department Indicator       1999 non-null   object
#  31  Total Charges                        1999 non-null   float64
#  32  Total Costs                          1999 non-null   float64
# dtypes: float64(5), int64(4), object(24)
# memory usage: 515.5+ KB
# Hospital Data Summary Statistics:
#        Operating Certificate Number  Permanent Facility Id  Discharge Year  \
# count                  1.990000e+03            1990.000000          1999.0
# mean                   6.843446e+06            1413.225126          2021.0
# std                    5.372404e+05             437.443397             0.0
# min                    4.324000e+06             776.000000          2021.0
# 25%                    7.000006e+06            1172.000000          2021.0
# 50%                    7.001016e+06            1301.000000          2021.0
# 75%                    7.002009e+06            1456.000000          2021.0
# max                    7.003007e+06            3058.000000          2021.0
#
#        APR DRG Code  APR MDC Code  APR Severity of Illness Code  Birth Weight  \
# count    1999.00000   1999.000000                   1999.000000    399.000000
# mean      491.89945     12.144072                      1.952976   3150.375940
# std       238.77991      5.888627                      0.844691    609.426462
# min         1.00000      1.000000                      1.000000    400.000000
# 25%       254.00000      6.000000                      1.000000   2900.000000
# 50%       560.00000     14.000000                      2.000000   3200.000000
# 75%       694.00000     16.000000                      2.000000   3500.000000
# max       951.00000     25.000000                      4.000000   5000.000000
#
#        Total Charges   Total Costs
# count   1.999000e+03  1.999000e+03
# mean    6.431233e+04  2.841500e+04
# std     2.229193e+05  6.990000e+04
# min     2.564830e+03  5.636700e+02
# 25%     1.712590e+04  6.963385e+03
# 50%     3.001320e+04  1.378871e+04
# 75%     6.110170e+04  2.872102e+04
# max     8.421962e+06  2.196834e+06
# Health Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   TimePeriod                       96 non-null     int64
#  1   GeoTypeDesc                      96 non-null     object
#  2   GeoID                            96 non-null     int64
#  3   GeoRank                          96 non-null     int64
#  4   Geography                        96 non-null     object
#  5   Age-adjusted rate per 10000      96 non-null     float64
#  6   Estimated annual rate per 10000  96 non-null     float64
#  7   Number                           96 non-null     object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.1+ KB
# Environmental Health Data Summary Statistics:
#         TimePeriod       GeoID    GeoRank  Age-adjusted rate per 10000  \
# count    96.000000   96.000000  96.000000                    96.000000
# mean   2021.500000  252.708333   3.604167                    53.014583
# std       0.502625  149.747149   1.061074                    41.515334
# min    2021.000000    1.000000   0.000000                     6.000000
# 25%    2021.000000  106.750000   4.000000                    22.325000
# 50%    2021.500000  256.000000   4.000000                    37.350000
# 75%    2022.000000  402.250000   4.000000                    74.925000
# max    2022.000000  504.000000   4.000000                   175.500000
#
#        Estimated annual rate per 10000
# count                        96.000000
# mean                         51.602083
# std                          41.675218
# min                           5.900000
# 25%                          20.475000
# 50%                          35.950000
# 75%                          75.325000
# max                         174.900000
# Air Quality Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16122 entries, 0 to 16121
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       16122 non-null  int64
#  1   Indicator ID    16122 non-null  int64
#  2   Name            16122 non-null  object
#  3   Measure         16122 non-null  object
#  4   Measure Info    16122 non-null  object
#  5   Geo Type Name   16122 non-null  object
#  6   Geo Join ID     16122 non-null  int64
#  7   Geo Place Name  16122 non-null  object
#  8   Time Period     16122 non-null  object
#  9   Start_Date      16122 non-null  object
#  10  Data Value      16122 non-null  float64
#  11  Message         0 non-null      float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 1.5+ MB
# Air Quality Data Summary Statistics:
#            Unique ID  Indicator ID   Geo Join ID    Data Value  Message
# count   16122.000000  16122.000000  1.612200e+04  16122.000000      0.0
# mean   339480.955589    427.131063  6.133394e+05     19.129163      NaN
# std    194099.809551    109.657607  7.916715e+06     21.673789      NaN
# min    130355.000000    365.000000  1.000000e+00      0.000000      NaN
# 25%    172183.250000    365.000000  2.020000e+02      8.460000      NaN
# 50%    221882.500000    375.000000  3.030000e+02     13.900000      NaN
# 75%    547749.750000    386.000000  4.040000e+02     25.470000      NaN
# max    671122.000000    661.000000  1.051061e+08    424.700000      NaN

# %%
#Handling Missing Values

print("Hospital Data - Missing Values:")
display(hospital_data.isnull().sum())

print("Environmental Health Data - Missing Values:")
display(health_data.isnull().sum())

print("Air Quality Data - Missing Values:")
display(air_quality_data.isnull().sum())
# Out:
# Hospital Data - Missing Values:
# Hospital Service Area                     9
# Hospital County                           9
# Operating Certificate Number              9
# Permanent Facility Id                     9
# Facility Name                             0
# Age Group                                 0
# Zip Code - 3 digits                      45
# Gender                                    0
# Race                                      0
# Ethnicity                                 0
# Length of Stay                            0
# Type of Admission                         0
# Patient Disposition                       0
# Discharge Year                            0
# CCSR Diagnosis Code                       0
# CCSR Diagnosis Description                0
# CCSR Procedure Code                     470
# CCSR Procedure Description              470
# APR DRG Code                              0
# APR DRG Description                       0
# APR MDC Code                              0
# APR MDC Description                       0
# APR Severity of Illness Code              0
# APR Severity of Illness Description       0
# APR Risk of Mortality                     0
# APR Medical Surgical Description          0
# Payment Typology 1                        0
# Payment Typology 2                     1363
# Payment Typology 3                     1810
# Birth Weight                           1600
# Emergency Department Indicator            0
# Total Charges                             0
# Total Costs                               0
# dtype: int64
# Environmental Health Data - Missing Values:
# TimePeriod                         0
# GeoTypeDesc                        0
# GeoID                              0
# GeoRank                            0
# Geography                          0
# Age-adjusted rate per 10000        0
# Estimated annual rate per 10000    0
# Number                             0
# dtype: int64
# Air Quality Data - Missing Values:
# Unique ID             0
# Indicator ID          0
# Name                  0
# Measure               0
# Measure Info          0
# Geo Type Name         0
# Geo Join ID           0
# Geo Place Name        0
# Time Period           0
# Start_Date            0
# Data Value            0
# Message           16122
# dtype: int64

# %%
# Handling missing values - Drop rows with missing 'Total Charges' or 'Total Costs'
hospital_data = hospital_data.dropna(subset=['Total Charges', 'Total Costs'])

# For air_quality_data, we can impute missing 'Data Value' with the median
air_quality_data['Data Value'] = air_quality_data['Data Value'].fillna(air_quality_data['Data Value'].median())

# For health_data, fill missing 'Age-adjusted rate' with the median
health_data.columns = health_data.columns.str.strip()
health_data['Age-adjusted rate per 10000'] = health_data['Age-adjusted rate per 10000'].fillna(
    health_data['Age-adjusted rate per 10000'].median())

# %%
air_quality_data = air_quality_data.drop(columns=['Message'])

# %%
# Drop columns with more than 50% missing values
hospital_data = hospital_data.drop(columns=['Payment Typology 2', 'Payment Typology 3', 'Birth Weight'])
# Drop rows with missing values in critical identifier columns
hospital_data = hospital_data.dropna(subset=['Hospital Service Area', 'Hospital County', 'Operating Certificate Number', 'Permanent Facility Id'])
# Impute categorical columns with mode
hospital_data['APR Severity of Illness Description'].fillna(hospital_data['APR Severity of Illness Description'].mode()[0], inplace=True)
hospital_data['APR Risk of Mortality'].fillna(hospital_data['APR Risk of Mortality'].mode()[0], inplace=True)
# Fill missing ZIP codes with mode, or use another location-based logic if possible
hospital_data['Zip Code - 3 digits'].fillna(hospital_data['Zip Code - 3 digits'].mode()[0], inplace=True)
# Fill missing values in CCSR columns with "Not Available"
hospital_data['CCSR Procedure Code'].fillna("Not Available", inplace=True)
hospital_data['CCSR Procedure Description'].fillna("Not Available", inplace=True)
# Out:
# /var/folders/jv/h3dx189d6plbqcdlrhctq9jc0000gn/T/ipykernel_32980/694467584.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_data['APR Severity of Illness Description'].fillna(hospital_data['APR Severity of Illness Description'].mode()[0], inplace=True)
# /var/folders/jv/h3dx189d6plbqcdlrhctq9jc0000gn/T/ipykernel_32980/694467584.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_data['APR Risk of Mortality'].fillna(hospital_data['APR Risk of Mortality'].mode()[0], inplace=True)
# /var/folders/jv/h3dx189d6plbqcdlrhctq9jc0000gn/T/ipykernel_32980/694467584.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_data['Zip Code - 3 digits'].fillna(hospital_data['Zip Code - 3 digits'].mode()[0], inplace=True)
# /var/folders/jv/h3dx189d6plbqcdlrhctq9jc0000gn/T/ipykernel_32980/694467584.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_data['CCSR Procedure Code'].fillna("Not Available", inplace=True)
# /var/folders/jv/h3dx189d6plbqcdlrhctq9jc0000gn/T/ipykernel_32980/694467584.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   hospital_data['CCSR Procedure Description'].fillna("Not Available", inplace=True)

# %%
# Confirm that the missing values are handled
print("Hospital Data - Missing Values After Handling:")
display(hospital_data.isnull().sum())

print("Environmental Health Data - Missing Values After Handling:")
display(health_data.isnull().sum())

print("Air Quality Data - Missing Values After Handling:")
display(air_quality_data.isnull().sum())
print(health_data.columns)
# Out:
# Hospital Data - Missing Values After Handling:
# Hospital Service Area                  0
# Hospital County                        0
# Operating Certificate Number           0
# Permanent Facility Id                  0
# Facility Name                          0
# Age Group                              0
# Zip Code - 3 digits                    0
# Gender                                 0
# Race                                   0
# Ethnicity                              0
# Length of Stay                         0
# Type of Admission                      0
# Patient Disposition                    0
# Discharge Year                         0
# CCSR Diagnosis Code                    0
# CCSR Diagnosis Description             0
# CCSR Procedure Code                    0
# CCSR Procedure Description             0
# APR DRG Code                           0
# APR DRG Description                    0
# APR MDC Code                           0
# APR MDC Description                    0
# APR Severity of Illness Code           0
# APR Severity of Illness Description    0
# APR Risk of Mortality                  0
# APR Medical Surgical Description       0
# Payment Typology 1                     0
# Emergency Department Indicator         0
# Total Charges                          0
# Total Costs                            0
# dtype: int64
# Environmental Health Data - Missing Values After Handling:
# TimePeriod                         0
# GeoTypeDesc                        0
# GeoID                              0
# GeoRank                            0
# Geography                          0
# Age-adjusted rate per 10000        0
# Estimated annual rate per 10000    0
# Number                             0
# dtype: int64
# Air Quality Data - Missing Values After Handling:
# Unique ID         0
# Indicator ID      0
# Name              0
# Measure           0
# Measure Info      0
# Geo Type Name     0
# Geo Join ID       0
# Geo Place Name    0
# Time Period       0
# Start_Date        0
# Data Value        0
# dtype: int64
# Index(['TimePeriod', 'GeoTypeDesc', 'GeoID', 'GeoRank', 'Geography',
#        'Age-adjusted rate per 10000', 'Estimated annual rate per 10000',
#        'Number'],
#       dtype='object')

# %%
# Finding Duplicate Values

#Check for duplicate rows in each dataset
print("Hospital Data - Duplicates:")
hospital_data_duplicates = hospital_data.duplicated().sum()

print("Environmental Health Data - Duplicates:")
health_data_duplicates = health_data.duplicated().sum()

print("Air Quality Data - Duplicates:")
air_quality_data_duplicates = air_quality_data.duplicated().sum()

# Remove duplicates if found
if hospital_data_duplicates > 0:
    hospital_data = hospital_data.drop_duplicates()

if health_data_duplicates > 0:
    health_data = health_data.drop_duplicates()

if air_quality_data_duplicates > 0:
    air_quality_data = air_quality_data.drop_duplicates()
# Out:
# Hospital Data - Duplicates:
# Environmental Health Data - Duplicates:
# Air Quality Data - Duplicates:

# %%
# Confirm no duplicates are present
print(f"Hospital Data - Duplicates After Removal: {hospital_data.duplicated().sum()}")
print(f"Environmental Health Data - Duplicates After Removal: {health_data.duplicated().sum()}")
print(f"Air Quality Data - Duplicates After Removal: {air_quality_data.duplicated().sum()}")
# Out:
# Hospital Data - Duplicates After Removal: 0
# Environmental Health Data - Duplicates After Removal: 0
# Air Quality Data - Duplicates After Removal: 0

# %%
#Data type Conversion
# Convert 'Discharge Year' to categorical
hospital_data['Discharge Year'] = hospital_data['Discharge Year'].astype('category')

# Convert 'Start_Date' to datetime
air_quality_data['Start_Date'] = pd.to_datetime(air_quality_data['Start_Date'], errors='coerce')

# Convert 'GeoID' in health_data to categorical
health_data['GeoID'] = health_data['GeoID'].astype('category')

# Check data types after conversion
print("Hospital Data - Data Types After Conversion:")
print(hospital_data.dtypes)

print("Environmental Health Data - Data Types After Conversion:")
print(health_data.dtypes)

print("Air Quality Data - Data Types After Conversion:")
print(air_quality_data.dtypes)
# Out:
# Hospital Data - Data Types After Conversion:
# Hospital Service Area                    object
# Hospital County                          object
# Operating Certificate Number            float64
# Permanent Facility Id                   float64
# Facility Name                            object
# Age Group                                object
# Zip Code - 3 digits                      object
# Gender                                   object
# Race                                     object
# Ethnicity                                object
# Length of Stay                           object
# Type of Admission                        object
# Patient Disposition                      object
# Discharge Year                         category
# CCSR Diagnosis Code                      object
# CCSR Diagnosis Description               object
# CCSR Procedure Code                      object
# CCSR Procedure Description               object
# APR DRG Code                              int64
# APR DRG Description                      object
# APR MDC Code                              int64
# APR MDC Description                      object
# APR Severity of Illness Code              int64
# APR Severity of Illness Description      object
# APR Risk of Mortality                    object
# APR Medical Surgical Description         object
# Payment Typology 1                       object
# Emergency Department Indicator           object
# Total Charges                           float64
# Total Costs                             float64
# dtype: object
# Environmental Health Data - Data Types After Conversion:
# TimePeriod                            int64
# GeoTypeDesc                          object
# GeoID                              category
# GeoRank                               int64
# Geography                            object
# Age-adjusted rate per 10000         float64
# Estimated annual rate per 10000     float64
# Number                               object
# dtype: object
# Air Quality Data - Data Types After Conversion:
# Unique ID                  int64
# Indicator ID               int64
# Name                      object
# Measure                   object
# Measure Info              object
# Geo Type Name             object
# Geo Join ID                int64
# Geo Place Name            object
# Time Period               object
# Start_Date        datetime64[ns]
# Data Value               float64
# dtype: object

# %%
#Outlier Detection and Handling

# Visualize outliers for 'Total Charges' in hospital_data using boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=hospital_data['Total Charges'])
plt.title('Boxplot of Total Charges')
plt.show()

# %%
# Handle outliers - Cap 'Total Charges' at the 99th percentile
upper_limit = hospital_data['Total Charges'].quantile(0.99)
hospital_data = hospital_data[hospital_data['Total Charges'] <= upper_limit]

# %%
# Re-check for outliers after handling
plt.figure(figsize=(12, 6))
sns.boxplot(x=hospital_data['Total Charges'])
plt.title('Boxplot of Total Charges')
plt.show()

# %%
#Data Analysis
#Hospital Data Analysis: Hospital discharges by gender and age group

# Group hospital data by 'Gender' and 'Age Group' to analyze discharges by these categories
hospital_discharge_gender_age = hospital_data.groupby(['Gender', 'Age Group']).size().unstack()

# Display the summary
hospital_discharge_gender_age
# Out:
# Age Group  0 to 17  18 to 29  30 to 49  50 to 69  70 or Older
# Gender
# F              245       167       266       184          151
# M              233       104       222       274          121

# %%
#Data Visualization 1: Bar Chart – Total Discharges by Gender and Age Group (Hospital Data)

# Group hospital data by 'Gender' and 'Age Group' to analyze discharges by these categories
hospital_discharge_gender_age = hospital_data.groupby(['Gender', 'Age Group']).size().unstack()

# %%
# Create a bar plot to visualize the number of hospital discharges by gender and age group
hospital_discharge_gender_age.plot(kind='bar', stacked=True, figsize=(10, 6))

# Adding titles and labels
plt.title('Hospital Discharges by Gender and Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Discharges')
plt.xticks(rotation=45)
plt.legend(title='Gender', loc='upper right')
#Display the Plot
plt.tight_layout()
plt.show()

# %%
# Data Visualization 2: Scatter Plot
# Scatter plot for NYC EH Data: Age-adjusted rate per 10,000 vs Estimated annual rate per 10,000

plt.figure(figsize=(10, 6))

# Plotting the scatter plot
sns.scatterplot(x='Age-adjusted rate per 10000', y='Estimated annual rate per 10000', data=health_data, alpha=0.6)

# Adding titles and labels
plt.title('Scatter Plot: Age-adjusted Rate vs Estimated Annual Rate per 10,000')
plt.xlabel('Age-adjusted Rate per 10,000')
plt.ylabel('Estimated Annual Rate per 10,000')

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Step 1: Extract the year from 'Start_Date' if it is not already done
air_quality_data['Year'] = air_quality_data['Start_Date'].dt.year

# Step 2: Create a DataFrame with 'Data Value' and 'Year' columns
data_value_year_df = air_quality_data[['Year', 'Data Value']].dropna()  # Remove missing values

# Step 3: Compute the correlation matrix between 'Data Value' and 'Year'
correlation_matrix = data_value_year_df.corr()

# Step 4: Create the heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

# Adding titles and labels
plt.title('Correlation Heatmap between Data Value and Year')
plt.tight_layout()
plt.show()
